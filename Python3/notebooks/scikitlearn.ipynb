# %% [markdown]
# <div style="color:red;background-color:black">
# Diamond Light Source
#
# <h1 style="color:red;background-color:antiquewhite"> Python Fundamentals: SciKitLearn</h1>
#
# ©2000-20 Chris Seddon
# </div>

# %% [markdown]
# ## 1
# Execute the following cell to activate styling for this tutorial

# %%
from IPython.display import HTML
HTML(f"<style>{open('my.css').read()}</style>")
# Out:
# <style>/* GLOBALS */
# /* body {background-color: #f7f7f7;} */
# .text_cell {background-color: cornsilk;}
# .code_cell { background-color: lightskyblue; }
# .selected { background-color: peachpuff; }
# .output { background-color: aliceblue; }
#
# </style>

# %% [markdown]
# ## 2

# %%
# %matplotlib inline
import PIL.Image as Image

''' Iris flowers are often used as an introduction to machine learning '''

img = Image.open("images/iris.png")
img.show()

# %% [markdown]
# ## 3

# %%
# %matplotlib inline
import os, sys
from PIL import Image


# os.chdir("images")
infile = "images/DSCF0437.jpg"
outfile = os.path.splitext(infile)[0] + ".flipped.jpg"
try:
    img = Image.open(infile)
    img = img.transpose(Image.FLIP_LEFT_RIGHT)
    img.show()
    #plt.imshow(image)
except IOError as e:
    print(e)

# %% [markdown]
# ## 4

# %%
# %cd ..
# Out:
# /Users/seddon/home/workspace/Python3/Python3/notebooks

# %% [markdown]
# ## 5

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread("images/DSCF0437.jpg")
plt.imshow(image)
plt.show()

# %% [markdown]
# ## 6

# %% [markdown]
# ## 7

# %% [markdown]
# ## 8

# %% [markdown]
# ## 9

# %% [markdown]
# ## 10

# %% [markdown]
# ## 11

# %% [markdown]
# ## 12

# %% [markdown]
# ## 13

# %% [markdown]
# ## 14

# %% [markdown]
# ## 15

# %% [markdown]
# ## 16

# %% [markdown]
# ## 17

# %% [markdown]
# ## 18

# %% [markdown]
# ## 19

# %% [markdown]
# ## 20
